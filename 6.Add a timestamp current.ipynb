# %%
# Databricks notebook source

from pyspark.sql import SparkSession
from pyspark.sql.functions import *

# Create Spark Session
spark = SparkSession.builder \
    .appName("IPL_DataFrame") \
    .getOrCreate()

# COMMAND ----------

# Read IPL CSV file
df_1 = spark.read \
    .format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("/Volumes/workspace/default/ipldata/ipldata.csv")

# Display first 5 records
df_1.show(5)

# COMMAND ----------

# Display schema
df_1.printSchema()

# COMMAND ----------

# Add new columns
df_2 = df_1 \
    .withColumn("Country", lit("INDIA")) \
    .withColumn("LOAD_DATE_TIMESTAMP", current_timestamp())

# Display result
df_2.show(5)

# COMMAND ----------
# Out:
# +--------+----------+------+--------------------+---------+-------+-------------------+--------------------+----+------------+-----------+---------+--------+-----------+-----------+----------+----------+-----+-------+----+-------+-------+---------+-----------------+-----------+-------------------+--------------------+-------------+-------------------+--------------------+------------+---------------+--------------+----------------+-------+----+
# |match_id|      date|season|               venue|     city|innings|       batting_team|        bowling_team|over|ball_in_over|ball_number|   batter|  bowler|non_striker|batter_runs|extra_runs|total_runs|wides|noballs|byes|legbyes|penalty|is_wicket|wicket_player_out|wicket_kind|       match_winner|         toss_winner|toss_decision|              team1|               team2|is_powerplay|is_middle_overs|is_death_overs|batting_team_won|seasons|year|
# +--------+----------+------+--------------------+---------+-------+-------------------+--------------------+----+------------+-----------+---------+--------+-----------+-----------+----------+----------+-----+-------+----+-------+-------+---------+-----------------+-----------+-------------------+--------------------+-------------+-------------------+--------------------+------------+---------------+--------------+----------------+-------+----+
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           1|          1|DA Warner|TS Mills|   S Dhawan|          0|         0|         0|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           2|          2|DA Warner|TS Mills|   S Dhawan|          0|         0|         0|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           3|          3|DA Warner|TS Mills|   S Dhawan|          4|         0|         4|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           4|          4|DA Warner|TS Mills|   S Dhawan|          0|         0|         0|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           5|          5|DA Warner|TS Mills|   S Dhawan|          0|         2|         2|    2|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|
# +--------+----------+------+--------------------+---------+-------+-------------------+--------------------+----+------------+-----------+---------+--------+-----------+-----------+----------+----------+-----+-------+----+-------+-------+---------+-----------------+-----------+-------------------+--------------------+-------------+-------------------+--------------------+------------+---------------+--------------+----------------+-------+----+
# only showing top 5 rows
# root
#  |-- match_id: integer (nullable = true)
#  |-- date: date (nullable = true)
#  |-- season: string (nullable = true)
#  |-- venue: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- innings: integer (nullable = true)
#  |-- batting_team: string (nullable = true)
#  |-- bowling_team: string (nullable = true)
#  |-- over: integer (nullable = true)
#  |-- ball_in_over: integer (nullable = true)
#  |-- ball_number: integer (nullable = true)
#  |-- batter: string (nullable = true)
#  |-- bowler: string (nullable = true)
#  |-- non_striker: string (nullable = true)
#  |-- batter_runs: integer (nullable = true)
#  |-- extra_runs: integer (nullable = true)
#  |-- total_runs: integer (nullable = true)
#  |-- wides: integer (nullable = true)
#  |-- noballs: integer (nullable = true)
#  |-- byes: integer (nullable = true)
#  |-- legbyes: integer (nullable = true)
#  |-- penalty: integer (nullable = true)
#  |-- is_wicket: integer (nullable = true)
#  |-- wicket_player_out: string (nullable = true)
#  |-- wicket_kind: string (nullable = true)
#  |-- match_winner: string (nullable = true)
#  |-- toss_winner: string (nullable = true)
#  |-- toss_decision: string (nullable = true)
#  |-- team1: string (nullable = true)
#  |-- team2: string (nullable = true)
#  |-- is_powerplay: integer (nullable = true)
#  |-- is_middle_overs: integer (nullable = true)
#  |-- is_death_overs: integer (nullable = true)
#  |-- batting_team_won: integer (nullable = true)
#  |-- seasons: string (nullable = true)
#  |-- year: integer (nullable = true)
#
# +--------+----------+------+--------------------+---------+-------+-------------------+--------------------+----+------------+-----------+---------+--------+-----------+-----------+----------+----------+-----+-------+----+-------+-------+---------+-----------------+-----------+-------------------+--------------------+-------------+-------------------+--------------------+------------+---------------+--------------+----------------+-------+----+-------+--------------------+
# |match_id|      date|season|               venue|     city|innings|       batting_team|        bowling_team|over|ball_in_over|ball_number|   batter|  bowler|non_striker|batter_runs|extra_runs|total_runs|wides|noballs|byes|legbyes|penalty|is_wicket|wicket_player_out|wicket_kind|       match_winner|         toss_winner|toss_decision|              team1|               team2|is_powerplay|is_middle_overs|is_death_overs|batting_team_won|seasons|year|Country| LOAD_DATE_TIMESTAMP|
# +--------+----------+------+--------------------+---------+-------+-------------------+--------------------+----+------------+-----------+---------+--------+-----------+-----------+----------+----------+-----+-------+----+-------+-------+---------+-----------------+-----------+-------------------+--------------------+-------------+-------------------+--------------------+------------+---------------+--------------+----------------+-------+----+-------+--------------------+
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           1|          1|DA Warner|TS Mills|   S Dhawan|          0|         0|         0|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|  INDIA|2026-08-20 17:14:...|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           2|          2|DA Warner|TS Mills|   S Dhawan|          0|         0|         0|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|  INDIA|2026-08-20 17:14:...|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           3|          3|DA Warner|TS Mills|   S Dhawan|          4|         0|         4|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|  INDIA|2026-08-20 17:14:...|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           4|          4|DA Warner|TS Mills|   S Dhawan|          0|         0|         0|    0|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|  INDIA|2026-08-20 17:14:...|
# | 1082591|2017-04-05|  2017|Rajiv Gandhi Inte...|Hyderabad|      1|Sunrisers Hyderabad|Royal Challengers...|   0|           5|          5|DA Warner|TS Mills|   S Dhawan|          0|         2|         2|    2|      0|   0|      0|      0|        0|             NULL|       NULL|Sunrisers Hyderabad|Royal Challengers...|        field|Sunrisers Hyderabad|Royal Challengers...|           1|              0|             0|               1|   2017|2017|  INDIA|2026-08-20 17:14:...|
# +--------+----------+------+--------------------+---------+-------+-------------------+--------------------+----+------------+-----------+---------+--------+-----------+-----------+----------+----------+-----+-------+----+-------+-------+---------+-----------------+-----------+-------------------+--------------------+-------------+-------------------+--------------------+------------+---------------+--------------+----------------+-------+----+-------+--------------------+
# only showing top 5 rows
